# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_1=pd.read_csv('train.csv')

# %%
data=pd.read_csv('test.csv')

# %%
train=pd.concat([train_1,data])

# %%
data.head(2)
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0         -0.674302         -0.894088  ...                        -0.705974
# 1         -0.945823         -0.894088  ...                        -0.594944
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                     0.006462                               0.16292
# 1                    -0.083495                               0.01750
#
# ...

# %%
data['subject'].value_counts()
# Out:
# subject
# 24    381
# 18    364
# 20    354
# 13    327
# 12    320
# 4     317
# 2     302
# 10    294
# 9     288
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2947 entries, 0 to 2946
# Columns: 563 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), int64(1), object(1)
# memory usage: 12.7+ MB

# %%
data.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        2947.000000        2947.000000        2947.000000
# mean            0.273996          -0.017863          -0.108386
# std             0.060570           0.025745           0.042747
# min            -0.592004          -0.362884          -0.576184
# 25%             0.262075          -0.024961          -0.121162
# 50%             0.277113          -0.016967          -0.108458
# 75%             0.288097          -0.010143          -0.097123
# max             0.671887           0.246106           0.494114
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       2947.000000       2947.000000       2947.000000       2947.000000
# mean          -0.613635         -0.508330         -0.633797         -0.641278
# std            0.412597          0.494269          0.362699          0.385199
# min           -0.999606         -1.000000         -0.998955         -0.999417
# ...

# %%
data.shape
# Out:
# (2947, 563)

# %%
train.shape
# Out:
# (10299, 563)

# %%
print(train.isnull().sum().sort_values(ascending=False).head(10))
# Out:
# Activity                       0
# tBodyAcc-mean()-X              0
# tBodyAcc-mean()-Y              0
# fBodyBodyGyroJerkMag-sma()     0
# fBodyBodyGyroJerkMag-min()     0
# fBodyBodyGyroJerkMag-max()     0
# fBodyBodyGyroJerkMag-mad()     0
# fBodyBodyGyroJerkMag-std()     0
# fBodyBodyGyroJerkMag-mean()    0
# fBodyBodyGyroMag-kurtosis()    0
# dtype: int64

# %%
print(data.isnull().sum().sort_values(ascending=False).head(10))
# Out:
# Activity                       0
# tBodyAcc-mean()-X              0
# tBodyAcc-mean()-Y              0
# fBodyBodyGyroJerkMag-sma()     0
# fBodyBodyGyroJerkMag-min()     0
# fBodyBodyGyroJerkMag-max()     0
# fBodyBodyGyroJerkMag-mad()     0
# fBodyBodyGyroJerkMag-std()     0
# fBodyBodyGyroJerkMag-mean()    0
# fBodyBodyGyroMag-kurtosis()    0
# dtype: int64

# %%
plt.figure(figsize=(8,4))
sns.countplot(data=train, x='Activity', palette='Set2')
plt.title("Distribution of Activities")
plt.xticks(rotation=30)
plt.show()
# Out:
# C:\Users\Nagaprasad M\AppData\Local\Temp\ipykernel_37940\2905300659.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=train, x='Activity', palette='Set2')

# %%
if 'subject' in train.columns:
    print("\nNumber of unique subjects:", train['subject'].nunique())
    print(train.groupby('Activity')['subject'].nunique())
# Out:
# Number of unique subjects: 30
# Activity
# LAYING                30
# SITTING               30
# STANDING              30
# WALKING               30
# WALKING_DOWNSTAIRS    30
# WALKING_UPSTAIRS      30
# Name: subject, dtype: int64

# %%
skewness=train.drop('Activity',axis=1).skew()
print(skewness)
# Out:
# tBodyAcc-mean()-X                      -3.490402
# tBodyAcc-mean()-Y                      -0.429086
# tBodyAcc-mean()-Z                       1.759648
# tBodyAcc-std()-X                        0.637015
# tBodyAcc-std()-Y                        0.435296
#                                           ...
# angle(tBodyGyroJerkMean,gravityMean)    0.017421
# angle(X,gravityMean)                    1.423169
# angle(Y,gravityMean)                   -1.425668
# angle(Z,gravityMean)                   -0.907224
# subject                                -0.123430
# Length: 562, dtype: float64

# %%
numeric_col=data.select_dtypes(include=['int64','float64'])

# %%
train['Activity'].value_counts()
# Out:
# Activity
# LAYING                1944
# STANDING              1906
# SITTING               1777
# WALKING               1722
# WALKING_UPSTAIRS      1544
# WALKING_DOWNSTAIRS    1406
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import PowerTransformer

# %%
for col in skewness.index:
    if (skewness[col] > 0.5) or (skewness[col] < -0.5):
        # Only transform if values are non-negative and all >0
        if (train[col] > 0).all():
            train[col] = np.log1p(train[col])
        # If values are >= 0, you can use np.log1p safely_copy
        elif (train[col] >= 0).all():
            train[col] = np.log1p(train[col])
        else:
            pt = PowerTransformer(method='yeo-johnson')
            train[col] = pt.fit_transform(train[[col]])

# %%
plt.figure(figsize=(14,10))
sns.heatmap(train.iloc[:, :20].corr(), cmap='coolwarm', center=0,annot=True)
plt.title("Correlation Heatmap (First 20 Features)")
plt.show()

# %%
num_features = [col for col in train.columns if col not in ['subject', 'Activity']]
plt.figure(figsize=(10,6))
sns.histplot(train[num_features[0]], kde=True, color='skyblue')
plt.title(f"Distribution of {num_features[0]}")
plt.show()

# %%
num_cols = train.select_dtypes(include=[np.number]).columns
Q1 = train[num_cols].quantile(0.25)
Q3 = train[num_cols].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = ((train[num_cols] < lower_bound) | (train[num_cols] > upper_bound))
outlier_counts = outliers.sum().sort_values(ascending=False)

# %%
# num_cols = train.select_dtypes(include=[np.number]).columns
# Q1 = train[num_cols].quantile(0.25)
# Q3 = train[num_cols].quantile(0.75)
# IQR = Q3 - Q1
# lower_bound = Q1 - 1.5 * IQR
# upper_bound = Q3 + 1.5 * IQR
# mask = ~((train[num_cols] < lower_bound) | (train[num_cols] > upper_bound)).any(axis=1)
# train_clean = train[mask]

# print(f"Original shape: {train.shape}")
# print(f"After removing outliers: {train_clean.shape}")

# %%
train['Activity']=='STANDING'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 2942    False
# 2943    False
# 2944    False
# 2945    False
# 2946    False
# Name: Activity, Length: 10299, dtype: bool

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.utils import to_categorical


data = pd.read_csv('train.csv')


X = data.drop(['Activity', 'subject'], axis=1)
y = data['Activity']


le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_categorical = to_categorical(y_encoded)


X_train, X_test, y_train, y_test = train_test_split(
    X, y_categorical, test_size=0.2, random_state=42
)
sc = StandardScaler()
X_train_scaled = sc.fit_transform(X_train)
X_test_scaled = sc.transform(X_test)
X_train_scaled = X_train_scaled.reshape(X_train_scaled.shape[0], 1, X_train_scaled.shape[1])
X_test_scaled = X_test_scaled.reshape(X_test_scaled.shape[0], 1, X_test_scaled.shape[1])

model = Sequential()
model.add(LSTM(64, input_shape=(1, X_train_scaled.shape[2]), return_sequences=False))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dense(y_categorical.shape[1], activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])


model.fit(X_train_scaled, y_train, epochs=15, batch_size=32, validation_data=(X_test_scaled, y_test))


X_scaled = sc.transform(X)  
X_scaled = X_scaled.reshape(X_scaled.shape[0], 1, X_scaled.shape[1])

preds = model.predict(X_scaled)
pred_classes = np.argmax(preds, axis=1)
pred_labels = le.inverse_transform(pred_classes)

print("\n🎯 Predictions:")
print(pred_labels[:10])
# Out:
# Epoch 1/15
# c:\Users\Nagaprasad M\anaconda4\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7881 - loss: 0.6030 - val_accuracy: 0.9436 - val_loss: 0.1943
# Epoch 2/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9378 - loss: 0.1886 - val_accuracy: 0.9531 - val_loss: 0.1329
# Epoch 3/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9476 - loss: 0.1439 - val_accuracy: 0.9680 - val_loss: 0.0951
# Epoch 4/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9667 - loss: 0.1005 - val_accuracy: 0.9592 - val_loss: 0.1161
# Epoch 5/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9675 - loss: 0.0881 - val_accuracy: 0.9728 - val_loss: 0.0800
# Epoch 6/15
# ...

# %%
data['Activity'].value_counts()
# Out:
# Activity
# LAYING                537
# STANDING              532
# WALKING               496
# SITTING               491
# WALKING_UPSTAIRS      471
# WALKING_DOWNSTAIRS    420
# Name: count, dtype: int64

# %%
print("\nSample Predictions:")
print(pred_labels[1600:1650])
# Out:
# Sample Predictions:
# ['SITTING' 'SITTING' 'SITTING' 'SITTING' 'SITTING' 'STANDING' 'STANDING'
#  'STANDING' 'STANDING' 'STANDING' 'STANDING' 'STANDING' 'STANDING'
#  'STANDING' 'STANDING' 'STANDING' 'STANDING' 'STANDING' 'STANDING'
#  'STANDING' 'STANDING' 'STANDING' 'STANDING' 'STANDING' 'STANDING'
#  'STANDING' 'STANDING' 'STANDING' 'STANDING' 'STANDING' 'STANDING'
#  'STANDING' 'STANDING' 'STANDING' 'STANDING' 'STANDING' 'STANDING'
#  'STANDING' 'STANDING' 'STANDING' 'STANDING' 'STANDING' 'STANDING'
#  'STANDING' 'STANDING' 'STANDING' 'STANDING' 'STANDING' 'STANDING'
#  'STANDING']

# %%
import pickle

model.save("model_lstm.h5")

with open("scaler.pkl", "wb") as f:
    pickle.dump(sc, f)

with open("label_encoder.pkl", "wb") as f:
    pickle.dump(le, f)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
